# %% [markdown]
# # Final evaluation
# The first cell automatically selects the repository root.

# %%
# Make imports work whether VS Code starts in the repository or notebooks folder.
import os
import sys
from pathlib import Path

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
if not (ROOT / "src").exists():
    raise RuntimeError(f"Cannot find the project root from {Path.cwd()}")
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
print("Project root:", ROOT)
# Out:
# Project root: c:\Users\jahav\OneDrive\janudrive\project\EV-Charging-RL-Optimizer

# %%
from src.evaluation.compare_models import compare
# Extend evaluation seeds/config for peak, off-peak, rain, clear, demand and initial-congestion scenarios.
table=compare(); display(table)
# Out:
#           model  mean_reward  mean_travel_minutes  mean_wait_minutes  mean_charge_minutes  mean_estimated_cost_inr  mean_average_queue  mean_maximum_queue  mean_mean_utilization  mean_maximum_utilization  mean_utilization_imbalance  failure_rate  mean_reward_std
#        Cheapest    89.123488            10.488483           0.000000            35.755246               438.033721            0.000000            0.000000               0.227556                  0.500000                    0.239125           0.0         1.354445
#    Maximum Free    89.123488            10.488483           0.000000            35.755246               438.033721            0.000000            0.000000               0.227556                  0.500000                    0.239125           0.0         1.354445
# Weighted Greedy    87.617260             7.643416           0.000000            34.804182               449.189555            0.000000            0.000000               0.222000                  0.790000                    0.283030           0.0         3.267670
#   Minimum Queue    86.518412             7.455964           0.535012            35.557472               456.219385            0.008000            0.120000               0.226667                  0.860000                    0.304448           0.0         4.403782
#         Nearest    86.458405             7.446495           0.675395            35.557472               456.716337            0.010222            0.153333               0.226667                  0.863333                    0.303968           0.0         4.648543
#             PPO    83.541464            12.126511           1.933250            37.931755               468.765773            0.018222            0.266667               0.229778                  0.940000                    0.331668           0.0         5.778485
#             DQN    83.541464            12.126511           1.933250            37.931755               468.765773            0.018222            0.266667               0.229778                  0.940000                    0.331668           0.0         5.778485
#          Random    81.861949            24.103979           1.855694            38.591099               466.155572            0.027556            0.340000               0.239333                  0.926667                    0.323939           0.0         6.713731
# {'best_evaluated_model': 'Cheapest', 'selection_basis': 'highest mean reward; only models actually evaluated are included'}
#              model  mean_reward  mean_travel_minutes  mean_wait_minutes  \
# 3         Cheapest    89.123488            10.488483           0.000000
# 4     Maximum Free    89.123488            10.488483           0.000000
# 5  Weighted Greedy    87.617260             7.643416           0.000000
# 2    Minimum Queue    86.518412             7.455964           0.535012
# 1          Nearest    86.458405             7.446495           0.675395
# 6              PPO    83.541464            12.126511           1.933250
# 7              DQN    83.541464            12.126511           1.933250
# 0           Random    81.861949            24.103979           1.855694
#
#    mean_charge_minutes  mean_estimated_cost_inr  mean_average_queue  \
# 3            35.755246               438.033721            0.000000
# 4            35.755246               438.033721            0.000000
# 5            34.804182               449.189555            0.000000
# 2            35.557472               456.219385            0.008000
# 1            35.557472               456.716337            0.010222
# 6            37.931755               468.765773            0.018222
# 7            37.931755               468.765773            0.018222
# 0            38.591099               466.155572            0.027556
#
#    mean_maximum_queue  mean_mean_utilization  mean_maximum_utilization  \
# 3            0.000000               0.227556                  0.500000
# 4            0.000000               0.227556                  0.500000
# 5            0.000000               0.222000                  0.790000
# 2            0.120000               0.226667                  0.860000
# 1            0.153333               0.226667                  0.863333
# 6            0.266667               0.229778                  0.940000
# 7            0.266667               0.229778                  0.940000
# 0            0.340000               0.239333                  0.926667
#
#    mean_utilization_imbalance  failure_rate  mean_reward_std
# 3                    0.239125           0.0         1.354445
# 4                    0.239125           0.0         1.354445
# 5                    0.283030           0.0         3.267670
# 2                    0.304448           0.0         4.403782
# 1                    0.303968           0.0         4.648543
# 6                    0.331668           0.0         5.778485
# 7                    0.331668           0.0         5.778485
# 0                    0.323939           0.0         6.713731

# %%
print('Report mean ± standard deviation; do not reuse training seeds for the final report.')
# Out:
# Report mean ± standard deviation; do not reuse training seeds for the final report.

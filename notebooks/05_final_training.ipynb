# %% [markdown]
# # Final training
# The first cell automatically selects the repository root.

# %%
# Make imports work whether VS Code starts in the repository or notebooks folder.
import os
import sys
from pathlib import Path

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
if not (ROOT / "src").exists():
    raise RuntimeError(f"Cannot find the project root from {Path.cwd()}")
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
print("Project root:", ROOT)
# Out:
# Project root: c:\Users\jahav\OneDrive\janudrive\project\EV-Charging-RL-Optimizer

# %%
from src.rl.train_ppo import train
# Increase config/default.yaml training budget for the final experiment.
model=train('default')
print('Saved:', 'models/ppo_ev_charging.zip')
# Out:
# Environment validation passed.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to C:\Users\jahav\OneDrive\janudrive\project\EV-Charging-RL-Optimizer\results\logs\ppo\PPO_4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 7.51e+03 |
# | time/              |          |
# |    fps             | 67       |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 128      |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.26e+03      |
# | time/                   |               |
# |    fps                  | 65            |
# |    iterations           | 2             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | 4.8091635e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | -0.000303     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.08e+05      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.0012       |
# |    value_loss           | 1.06e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.37e+03     |
# | time/                   |              |
# |    fps                  | 65           |
# |    iterations           | 3            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 384          |
# | train/                  |              |
# |    approx_kl            | 2.262555e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.000227     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.21e+05     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000418    |
# |    value_loss           | 9.17e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.42e+03      |
# | time/                   |               |
# |    fps                  | 66            |
# |    iterations           | 4             |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 512           |
# | train/                  |               |
# |    approx_kl            | 6.3746236e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.000346      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.72e+05      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.00137      |
# |    value_loss           | 1.11e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.49e+03     |
# | time/                   |              |
# |    fps                  | 67           |
# |    iterations           | 5            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 640          |
# | train/                  |              |
# |    approx_kl            | 6.426219e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.00119      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.5e+05      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00139     |
# |    value_loss           | 9.73e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.53e+03      |
# | time/                   |               |
# |    fps                  | 68            |
# |    iterations           | 6             |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 768           |
# | train/                  |               |
# |    approx_kl            | 7.9521444e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.000465      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.89e+05      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.00126      |
# |    value_loss           | 1.15e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.52e+03      |
# | time/                   |               |
# |    fps                  | 67            |
# |    iterations           | 7             |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 896           |
# | train/                  |               |
# |    approx_kl            | 4.5944937e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.000664      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.34e+05      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000697     |
# |    value_loss           | 1.05e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.58e+03     |
# | time/                   |              |
# |    fps                  | 68           |
# |    iterations           | 8            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 3.606733e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.000776     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.23e+05     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000777    |
# |    value_loss           | 1.14e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.59e+03      |
# | time/                   |               |
# |    fps                  | 68            |
# |    iterations           | 9             |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 1152          |
# | train/                  |               |
# |    approx_kl            | 3.1991396e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.000658      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.89e+05      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000883     |
# |    value_loss           | 1.17e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.6e+03       |
# | time/                   |               |
# |    fps                  | 69            |
# |    iterations           | 10            |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 1280          |
# | train/                  |               |
# |    approx_kl            | 5.3953845e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.0005        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.52e+05      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.00095      |
# |    value_loss           | 1.09e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.57e+03      |
# | time/                   |               |
# |    fps                  | 65            |
# |    iterations           | 11            |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 1408          |
# | train/                  |               |
# |    approx_kl            | 1.7469749e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.000639      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.7e+05       |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000354     |
# |    value_loss           | 1.02e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.55e+03     |
# | time/                   |              |
# |    fps                  | 60           |
# |    iterations           | 12           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 1536         |
# | train/                  |              |
# |    approx_kl            | 6.736163e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.000703     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.05e+05     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00162     |
# |    value_loss           | 1.03e+06     |
# ------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 100            |
# |    ep_rew_mean          | 7.54e+03       |
# | time/                   |                |
# |    fps                  | 56             |
# |    iterations           | 13             |
# |    time_elapsed         | 29             |
# |    total_timesteps      | 1664           |
# | train/                  |                |
# |    approx_kl            | 0.000121474266 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.3           |
# |    explained_variance   | 0.000292       |
# |    learning_rate        | 0.0003         |
# |    loss                 | 4.83e+05       |
# |    n_updates            | 120            |
# |    policy_gradient_loss | -0.00201       |
# |    value_loss           | 9.73e+05       |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.55e+03     |
# | time/                   |              |
# |    fps                  | 53           |
# |    iterations           | 14           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 1792         |
# | train/                  |              |
# |    approx_kl            | 6.764801e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.000196     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.35e+05     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 1.05e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.57e+03      |
# | time/                   |               |
# |    fps                  | 51            |
# |    iterations           | 15            |
# |    time_elapsed         | 37            |
# |    total_timesteps      | 1920          |
# | train/                  |               |
# |    approx_kl            | 6.2111765e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.000359      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.59e+05      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.00132      |
# |    value_loss           | 1.11e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.54e+03     |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 16           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 9.265682e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.000395     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.23e+05     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00209     |
# |    value_loss           | 1.1e+06      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.53e+03      |
# | time/                   |               |
# |    fps                  | 47            |
# |    iterations           | 17            |
# |    time_elapsed         | 45            |
# |    total_timesteps      | 2176          |
# | train/                  |               |
# |    approx_kl            | 4.0298793e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.000216      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.98e+05      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000658     |
# |    value_loss           | 9.83e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.53e+03     |
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 18           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 2304         |
# | train/                  |              |
# |    approx_kl            | 6.215554e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.00038      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.67e+05     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00113     |
# |    value_loss           | 9.61e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.51e+03      |
# | time/                   |               |
# |    fps                  | 45            |
# |    iterations           | 19            |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 2432          |
# | train/                  |               |
# |    approx_kl            | 3.0810013e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.000244      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.57e+05      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000719     |
# |    value_loss           | 1.1e+06       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.52e+03      |
# | time/                   |               |
# |    fps                  | 44            |
# |    iterations           | 20            |
# |    time_elapsed         | 57            |
# |    total_timesteps      | 2560          |
# | train/                  |               |
# |    approx_kl            | 4.0272716e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.000308      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5e+05         |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.000973     |
# |    value_loss           | 9.74e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.53e+03      |
# | time/                   |               |
# |    fps                  | 43            |
# |    iterations           | 21            |
# |    time_elapsed         | 61            |
# |    total_timesteps      | 2688          |
# | train/                  |               |
# |    approx_kl            | 8.3352905e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.000266      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.63e+05      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.00188      |
# |    value_loss           | 1.09e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.53e+03      |
# | time/                   |               |
# |    fps                  | 42            |
# |    iterations           | 22            |
# |    time_elapsed         | 66            |
# |    total_timesteps      | 2816          |
# | train/                  |               |
# |    approx_kl            | 3.2428652e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.000196      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.82e+05      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000491     |
# |    value_loss           | 1.19e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.54e+03     |
# | time/                   |              |
# |    fps                  | 41           |
# |    iterations           | 23           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 2944         |
# | train/                  |              |
# |    approx_kl            | 3.892416e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.000369     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.92e+05     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00103     |
# |    value_loss           | 9.34e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.54e+03     |
# | time/                   |              |
# |    fps                  | 41           |
# |    iterations           | 24           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 6.360421e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.000206     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.52e+05     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 1.15e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.52e+03      |
# | time/                   |               |
# |    fps                  | 42            |
# |    iterations           | 25            |
# |    time_elapsed         | 76            |
# |    total_timesteps      | 3200          |
# | train/                  |               |
# |    approx_kl            | 2.7677044e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.000307      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.2e+05       |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.000694     |
# |    value_loss           | 9.57e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.51e+03     |
# | time/                   |              |
# |    fps                  | 42           |
# |    iterations           | 26           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 3328         |
# | train/                  |              |
# |    approx_kl            | 6.797025e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.000196     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.58e+05     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 1.05e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.52e+03     |
# | time/                   |              |
# |    fps                  | 41           |
# |    iterations           | 27           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 3456         |
# | train/                  |              |
# |    approx_kl            | 7.528532e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.000152     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.7e+05      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00138     |
# |    value_loss           | 1.01e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.51e+03      |
# | time/                   |               |
# |    fps                  | 41            |
# |    iterations           | 28            |
# |    time_elapsed         | 87            |
# |    total_timesteps      | 3584          |
# | train/                  |               |
# |    approx_kl            | 1.6632956e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.000138      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.13e+05      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.00036      |
# |    value_loss           | 1.07e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.5e+03       |
# | time/                   |               |
# |    fps                  | 40            |
# |    iterations           | 29            |
# |    time_elapsed         | 91            |
# |    total_timesteps      | 3712          |
# | train/                  |               |
# |    approx_kl            | 2.6348047e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.000125      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.45e+05      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000452     |
# |    value_loss           | 9.66e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.49e+03      |
# | time/                   |               |
# |    fps                  | 41            |
# |    iterations           | 30            |
# |    time_elapsed         | 93            |
# |    total_timesteps      | 3840          |
# | train/                  |               |
# |    approx_kl            | 4.5309775e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.000182      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.79e+05      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.000719     |
# |    value_loss           | 9e+05         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.49e+03      |
# | time/                   |               |
# |    fps                  | 41            |
# |    iterations           | 31            |
# |    time_elapsed         | 95            |
# |    total_timesteps      | 3968          |
# | train/                  |               |
# |    approx_kl            | 3.1672884e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.000101      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.46e+05      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.000521     |
# |    value_loss           | 9.97e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.49e+03      |
# | time/                   |               |
# |    fps                  | 41            |
# |    iterations           | 32            |
# |    time_elapsed         | 99            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 3.9716717e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.000105      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.26e+05      |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000935     |
# |    value_loss           | 1e+06         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.5e+03      |
# | time/                   |              |
# |    fps                  | 40           |
# |    iterations           | 33           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 4224         |
# | train/                  |              |
# |    approx_kl            | 2.686074e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.000104     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.43e+05     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000784    |
# |    value_loss           | 1.15e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.51e+03      |
# | time/                   |               |
# |    fps                  | 40            |
# |    iterations           | 34            |
# |    time_elapsed         | 107           |
# |    total_timesteps      | 4352          |
# | train/                  |               |
# |    approx_kl            | 3.6019832e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.000124      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.4e+05       |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.000923     |
# |    value_loss           | 1.08e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.51e+03     |
# | time/                   |              |
# |    fps                  | 40           |
# |    iterations           | 35           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 4480         |
# | train/                  |              |
# |    approx_kl            | 6.236369e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 8.79e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.76e+05     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00169     |
# |    value_loss           | 1.13e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.51e+03      |
# | time/                   |               |
# |    fps                  | 39            |
# |    iterations           | 36            |
# |    time_elapsed         | 115           |
# |    total_timesteps      | 4608          |
# | train/                  |               |
# |    approx_kl            | 3.8678292e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.00015       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.63e+05      |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -0.000838     |
# |    value_loss           | 1.06e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.51e+03     |
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 37           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 4736         |
# | train/                  |              |
# |    approx_kl            | 2.344139e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.000117     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.38e+05     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000447    |
# |    value_loss           | 1.06e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.51e+03     |
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 38           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 4864         |
# | train/                  |              |
# |    approx_kl            | 4.263362e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 6.19e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.01e+05     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000852    |
# |    value_loss           | 1.01e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.51e+03     |
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 39           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 4992         |
# | train/                  |              |
# |    approx_kl            | 7.284153e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 6.75e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.02e+05     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 1.02e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.51e+03      |
# | time/                   |               |
# |    fps                  | 36            |
# |    iterations           | 40            |
# |    time_elapsed         | 138           |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 5.2460004e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 4.6e-05       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.98e+05      |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000882     |
# |    value_loss           | 1.08e+06      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 7.51e+03    |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 41          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 5248        |
# | train/                  |             |
# |    approx_kl            | 6.97528e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | 0.000102    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.16e+05    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00173    |
# |    value_loss           | 1.08e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.51e+03     |
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 42           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 5376         |
# | train/                  |              |
# |    approx_kl            | 5.494058e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 8.39e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.41e+05     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000734    |
# |    value_loss           | 1.07e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.51e+03      |
# | time/                   |               |
# |    fps                  | 36            |
# |    iterations           | 43            |
# |    time_elapsed         | 152           |
# |    total_timesteps      | 5504          |
# | train/                  |               |
# |    approx_kl            | 5.3205993e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.000115      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.99e+05      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.00118      |
# |    value_loss           | 1.03e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.52e+03     |
# | time/                   |              |
# |    fps                  | 35           |
# |    iterations           | 44           |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 5632         |
# | train/                  |              |
# |    approx_kl            | 7.108739e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 9.68e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.97e+05     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 1.06e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 7.52e+03    |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 45          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 5760        |
# | train/                  |             |
# |    approx_kl            | 4.85559e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | 4.3e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.47e+05    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00105    |
# |    value_loss           | 1.12e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.53e+03     |
# | time/                   |              |
# |    fps                  | 35           |
# |    iterations           | 46           |
# |    time_elapsed         | 165          |
# |    total_timesteps      | 5888         |
# | train/                  |              |
# |    approx_kl            | 7.568719e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 4.57e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.74e+05     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00173     |
# |    value_loss           | 1.15e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.54e+03     |
# | time/                   |              |
# |    fps                  | 35           |
# |    iterations           | 47           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 6016         |
# | train/                  |              |
# |    approx_kl            | 3.158534e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 5.89e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.84e+05     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000503    |
# |    value_loss           | 1.13e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.54e+03      |
# | time/                   |               |
# |    fps                  | 35            |
# |    iterations           | 48            |
# |    time_elapsed         | 173           |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 3.1075906e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.000114      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.32e+05      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.000739     |
# |    value_loss           | 1.03e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.55e+03      |
# | time/                   |               |
# |    fps                  | 35            |
# |    iterations           | 49            |
# |    time_elapsed         | 177           |
# |    total_timesteps      | 6272          |
# | train/                  |               |
# |    approx_kl            | 2.0432752e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 4.93e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.46e+05      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000524     |
# |    value_loss           | 1.16e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.56e+03      |
# | time/                   |               |
# |    fps                  | 35            |
# |    iterations           | 50            |
# |    time_elapsed         | 181           |
# |    total_timesteps      | 6400          |
# | train/                  |               |
# |    approx_kl            | 2.8196722e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 8.36e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.38e+05      |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.000729     |
# |    value_loss           | 1.11e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.55e+03     |
# | time/                   |              |
# |    fps                  | 35           |
# |    iterations           | 51           |
# |    time_elapsed         | 184          |
# |    total_timesteps      | 6528         |
# | train/                  |              |
# |    approx_kl            | 3.190199e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 7.77e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.21e+05     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000926    |
# |    value_loss           | 1.14e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.55e+03      |
# | time/                   |               |
# |    fps                  | 35            |
# |    iterations           | 52            |
# |    time_elapsed         | 186           |
# |    total_timesteps      | 6656          |
# | train/                  |               |
# |    approx_kl            | 2.1416228e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 5.76e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.91e+05      |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -0.00033      |
# |    value_loss           | 9.89e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.56e+03      |
# | time/                   |               |
# |    fps                  | 36            |
# |    iterations           | 53            |
# |    time_elapsed         | 188           |
# |    total_timesteps      | 6784          |
# | train/                  |               |
# |    approx_kl            | 2.6126858e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 5.81e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.77e+05      |
# |    n_updates            | 520           |
# ...
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 5.23e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.76e+05     |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.000748    |
# |    value_loss           | 1.06e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.55e+03     |
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 63           |
# |    time_elapsed         | 204          |
# |    total_timesteps      | 8064         |
# | train/                  |              |
# |    approx_kl            | 3.371341e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 1.9e-05      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.54e+05     |
# |    n_updates            | 620          |
# |    policy_gradient_loss | -0.000591    |
# |    value_loss           | 1.06e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.55e+03      |
# | time/                   |               |
# |    fps                  | 39            |
# |    iterations           | 64            |
# |    time_elapsed         | 206           |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 5.1734038e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 3.49e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.37e+05      |
# |    n_updates            | 630           |
# |    policy_gradient_loss | -0.00129      |
# |    value_loss           | 1.06e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.55e+03      |
# | time/                   |               |
# |    fps                  | 40            |
# |    iterations           | 65            |
# |    time_elapsed         | 207           |
# |    total_timesteps      | 8320          |
# | train/                  |               |
# |    approx_kl            | 3.5310164e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 1.19e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.01e+05      |
# |    n_updates            | 640           |
# |    policy_gradient_loss | -0.000813     |
# |    value_loss           | 1.15e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.55e+03     |
# | time/                   |              |
# |    fps                  | 40           |
# |    iterations           | 66           |
# |    time_elapsed         | 209          |
# |    total_timesteps      | 8448         |
# | train/                  |              |
# |    approx_kl            | 4.701037e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 3.34e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.05e+05     |
# |    n_updates            | 650          |
# |    policy_gradient_loss | -0.00118     |
# |    value_loss           | 1.01e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.54e+03     |
# | time/                   |              |
# |    fps                  | 40           |
# |    iterations           | 67           |
# |    time_elapsed         | 211          |
# |    total_timesteps      | 8576         |
# | train/                  |              |
# |    approx_kl            | 8.492591e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 1.44e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.99e+05     |
# |    n_updates            | 660          |
# |    policy_gradient_loss | -0.00189     |
# |    value_loss           | 9.91e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.55e+03     |
# | time/                   |              |
# |    fps                  | 40           |
# |    iterations           | 68           |
# |    time_elapsed         | 213          |
# |    total_timesteps      | 8704         |
# | train/                  |              |
# |    approx_kl            | 4.648883e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 3.46e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.14e+05     |
# |    n_updates            | 670          |
# |    policy_gradient_loss | -0.000817    |
# |    value_loss           | 1.07e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.55e+03     |
# | time/                   |              |
# |    fps                  | 40           |
# |    iterations           | 69           |
# |    time_elapsed         | 215          |
# |    total_timesteps      | 8832         |
# | train/                  |              |
# |    approx_kl            | 3.469456e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 3.37e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.06e+05     |
# |    n_updates            | 680          |
# |    policy_gradient_loss | -0.000682    |
# |    value_loss           | 1.11e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.55e+03      |
# | time/                   |               |
# |    fps                  | 41            |
# |    iterations           | 70            |
# |    time_elapsed         | 217           |
# |    total_timesteps      | 8960          |
# | train/                  |               |
# |    approx_kl            | 2.1371525e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 1.84e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.24e+05      |
# |    n_updates            | 690           |
# |    policy_gradient_loss | -0.000625     |
# |    value_loss           | 1.12e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.55e+03     |
# | time/                   |              |
# |    fps                  | 41           |
# |    iterations           | 71           |
# |    time_elapsed         | 219          |
# |    total_timesteps      | 9088         |
# | train/                  |              |
# |    approx_kl            | 3.894698e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 2.54e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.09e+05     |
# |    n_updates            | 700          |
# |    policy_gradient_loss | -0.000844    |
# |    value_loss           | 1.03e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.56e+03      |
# | time/                   |               |
# |    fps                  | 41            |
# |    iterations           | 72            |
# |    time_elapsed         | 220           |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 2.1714717e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 1.79e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.07e+05      |
# |    n_updates            | 710           |
# |    policy_gradient_loss | -0.000598     |
# |    value_loss           | 1.1e+06       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.55e+03      |
# | time/                   |               |
# |    fps                  | 42            |
# |    iterations           | 73            |
# |    time_elapsed         | 222           |
# |    total_timesteps      | 9344          |
# | train/                  |               |
# |    approx_kl            | 1.5168916e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 3.44e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.26e+05      |
# |    n_updates            | 720           |
# |    policy_gradient_loss | -0.000366     |
# |    value_loss           | 1.09e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.56e+03      |
# | time/                   |               |
# |    fps                  | 42            |
# |    iterations           | 74            |
# |    time_elapsed         | 224           |
# |    total_timesteps      | 9472          |
# | train/                  |               |
# |    approx_kl            | 3.7352555e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 5.9e-06       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.52e+05      |
# |    n_updates            | 730           |
# |    policy_gradient_loss | -0.00089      |
# |    value_loss           | 1.03e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.56e+03      |
# | time/                   |               |
# |    fps                  | 42            |
# |    iterations           | 75            |
# |    time_elapsed         | 225           |
# |    total_timesteps      | 9600          |
# | train/                  |               |
# |    approx_kl            | 3.3860095e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 4e-05         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.91e+05      |
# |    n_updates            | 740           |
# |    policy_gradient_loss | -0.000764     |
# |    value_loss           | 1.13e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.56e+03     |
# | time/                   |              |
# |    fps                  | 42           |
# |    iterations           | 76           |
# |    time_elapsed         | 227          |
# |    total_timesteps      | 9728         |
# | train/                  |              |
# |    approx_kl            | 6.229011e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 5.19e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.48e+05     |
# |    n_updates            | 750          |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 1.09e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.56e+03      |
# | time/                   |               |
# |    fps                  | 42            |
# |    iterations           | 77            |
# |    time_elapsed         | 229           |
# |    total_timesteps      | 9856          |
# | train/                  |               |
# |    approx_kl            | 6.4563006e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 1.82e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.1e+05       |
# |    n_updates            | 760           |
# |    policy_gradient_loss | -0.00128      |
# |    value_loss           | 9.78e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 7.56e+03      |
# | time/                   |               |
# |    fps                  | 43            |
# |    iterations           | 78            |
# |    time_elapsed         | 231           |
# |    total_timesteps      | 9984          |
# | train/                  |               |
# |    approx_kl            | 2.3535918e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 1.81e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.92e+05      |
# |    n_updates            | 770           |
# |    policy_gradient_loss | -0.000519     |
# |    value_loss           | 1.1e+06       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 7.56e+03     |
# | time/                   |              |
# |    fps                  | 43           |
# |    iterations           | 79           |
# |    time_elapsed         | 233          |
# |    total_timesteps      | 10112        |
# | train/                  |              |
# |    approx_kl            | 6.852951e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 3.3e-05      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.42e+05     |
# |    n_updates            | 780          |
# |    policy_gradient_loss | -0.00165     |
# |    value_loss           | 1.05e+06     |
# ------------------------------------------
# Saved: models/ppo_ev_charging.zip
